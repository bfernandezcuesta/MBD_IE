# %% [markdown]
# ### IMDB Homework - Individual Assignment

# %%
# loading the needed libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date, datetime
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# **Question 1**
#
# Open the dataset as a pandas DataFrame named imdb

# %%
imdb=pd.read_csv("imdb_2019.tsv", sep="\t")
imdb
# Out:
#             index     tconst  titleType  \
# 0         87501.0  tt0089435      short
# 1         89512.0  tt0091490      short
# 2        114407.0  tt0116991      movie
# 3        126556.0  tt0129960    tvMovie
# 4        166388.0  tt0172112      short
# ...           ...        ...        ...
# 301334  6591633.0  tt9916776  tvEpisode
# 301335  6591634.0  tt9916778  tvEpisode
# 301336  6591640.0  tt9916790  tvEpisode
# 301337  6591646.0  tt9916802  tvEpisode
# 301338  6591650.0  tt9916810  tvEpisode
#
#                                              primaryTitle  \
# 0                                                   Kokoa
# 1                                     Martina's Playhouse
# 2                                     Mariette in Ecstasy
# 3                          Eine geschlossene Gesellschaft
# 4                                                Ambulans
# ...                                                   ...
# 301334  Talent Coaching with IMOR's Bianca Desmore Mit...
# ...

# %% [markdown]
# **Question 2**
#
# How many types of titles are there in the column titleType?

# %%
# naming the unique values
uniqueValues = imdb['titleType'].unique()
uniqueValues
# Out:
# array(['short', 'movie', 'tvMovie', 'video', 'tvSeries', 'tvEpisode',
#        'tvMiniSeries', 'tvSpecial', 'videoGame', 'tvShort'], dtype=object)

# %%
# how many types in number?
len(uniqueValues)
# Out:
# 10

# %% [markdown]
# **Question 3**
#
# Create a slice of imdb that only contains the following columns:
# -  titleType, primaryTitle, startYear, runtimeMinutes

# %%
imdb_slice = imdb.loc[:, ["titleType", "primaryTitle", "startYear", "runtimeMinutes"]]
imdb_slice
# Out:
#         titleType                                       primaryTitle  \
# 0           short                                              Kokoa
# 1           short                                Martina's Playhouse
# 2           movie                                Mariette in Ecstasy
# 3         tvMovie                     Eine geschlossene Gesellschaft
# 4           short                                           Ambulans
# ...           ...                                                ...
# 301334  tvEpisode  Talent Coaching with IMOR's Bianca Desmore Mit...
# 301335  tvEpisode                                             Escape
# 301336  tvEpisode                                      Tinne Oltmans
# 301337  tvEpisode                                       Luc Janssens
# 301338  tvEpisode                       Danira Boukhriss Terkessidis
#
#         startYear  runtimeMinutes
# 0          2019.0            13.0
# 1          2019.0            20.0
# ...

# %% [markdown]
# **Question 4**
#
# Create a subset of imdb named tvEpisodes_2019 that only includes the type tvEpisodes

# %%
tvEpisodes_2019 = imdb.loc[imdb['titleType'] == "tvEpisode"]
tvEpisodes_2019
# Out:
#             index      tconst  titleType  \
# 21       758955.0   tt0782666  tvEpisode
# 30       969426.0  tt10001058  tvEpisode
# 32       969458.0  tt10001110  tvEpisode
# 34       969464.0  tt10001120  tvEpisode
# 35       969465.0  tt10001122  tvEpisode
# ...           ...         ...        ...
# 301334  6591633.0   tt9916776  tvEpisode
# 301335  6591634.0   tt9916778  tvEpisode
# 301336  6591640.0   tt9916790  tvEpisode
# 301337  6591646.0   tt9916802  tvEpisode
# 301338  6591650.0   tt9916810  tvEpisode
#
#                                              primaryTitle  \
# 21                                     Save the Duckling!
# 30                                          Le grand saut
# 32                                         The Interviews
# 34                                            The New Guy
# 35                                           The New Girl
# ...                                                   ...
# ...

# %% [markdown]
# **Question 5**
#
# Percentage of adult films over total releases in 2019

# %%
imdb.describe()
# Out:
#               index        isAdult  startYear      endYear  runtimeMinutes  \
# count  3.013390e+05  301339.000000   301339.0  2147.000000    79828.000000
# mean   2.456408e+06       0.029684     2019.0  2019.085701       40.498973
# std    1.960272e+06       0.169715        0.0     0.284936       53.452706
# min    8.750100e+04       0.000000     2019.0  2019.000000        1.000000
# 25%    1.292248e+06       0.000000     2019.0  2019.000000       11.000000
# 50%    1.597750e+06       0.000000     2019.0  2019.000000       27.000000
# 75%    1.927127e+06       0.000000     2019.0  2019.000000       56.000000
# max    6.591650e+06       1.000000     2019.0  2021.000000    10062.000000
#
#        genres
# count     0.0
# mean      NaN
# std       NaN
# min       NaN
# 25%       NaN
# 50%       NaN
# 75%       NaN
# max       NaN

# %%
adult_films_percetage = imdb["isAdult"].mean()
adult_films_percetage*100
# Out:
# 2.9684176293144926

# %% [markdown]
# **Question 6**
#
# Create a column named words_in_title that contains the total number of words in the title

# %%
imdb['words_in_title'] = imdb['originalTitle'].str.split().str.len()
imdb
# Out:
#             index     tconst  titleType  \
# 0         87501.0  tt0089435      short
# 1         89512.0  tt0091490      short
# 2        114407.0  tt0116991      movie
# 3        126556.0  tt0129960    tvMovie
# 4        166388.0  tt0172112      short
# ...           ...        ...        ...
# 301334  6591633.0  tt9916776  tvEpisode
# 301335  6591634.0  tt9916778  tvEpisode
# 301336  6591640.0  tt9916790  tvEpisode
# 301337  6591646.0  tt9916802  tvEpisode
# 301338  6591650.0  tt9916810  tvEpisode
#
#                                              primaryTitle  \
# 0                                                   Kokoa
# 1                                     Martina's Playhouse
# 2                                     Mariette in Ecstasy
# 3                          Eine geschlossene Gesellschaft
# 4                                                Ambulans
# ...                                                   ...
# 301334  Talent Coaching with IMOR's Bianca Desmore Mit...
# ...

# %%
# using map alongside a lambda function

imdb['words_in_title'] = imdb['originalTitle'].map(lambda x: len(str(x).split(' ')))
imdb
# Out:
#             index     tconst  titleType  \
# 0         87501.0  tt0089435      short
# 1         89512.0  tt0091490      short
# 2        114407.0  tt0116991      movie
# 3        126556.0  tt0129960    tvMovie
# 4        166388.0  tt0172112      short
# ...           ...        ...        ...
# 301334  6591633.0  tt9916776  tvEpisode
# 301335  6591634.0  tt9916778  tvEpisode
# 301336  6591640.0  tt9916790  tvEpisode
# 301337  6591646.0  tt9916802  tvEpisode
# 301338  6591650.0  tt9916810  tvEpisode
#
#                                              primaryTitle  \
# 0                                                   Kokoa
# 1                                     Martina's Playhouse
# 2                                     Mariette in Ecstasy
# 3                          Eine geschlossene Gesellschaft
# 4                                                Ambulans
# ...                                                   ...
# 301334  Talent Coaching with IMOR's Bianca Desmore Mit...
# ...

# %% [markdown]
# **Question 7**
#
# What’s the average value of runtimeMinutes for the type short?

# %%
short = imdb.loc[imdb["titleType"] == "short"]

# %%
short["runtimeMinutes"].mean()
# Out:
# 12.536104279390065

# %% [markdown]
# **Question 8**
#
# Filter imdb to return tvMovie type with 3 or more words in the title, and less than 75 minutes of runTimeMinutes

# %%
imdb[(imdb["titleType"] == "tvMovie") & (imdb["words_in_title"] >= 3) & (imdb["runtimeMinutes"] < 75)]
# Out:
#             index      tconst titleType  \
# 10       290068.0   tt0302617   tvMovie
# 77       970092.0  tt10002188   tvMovie
# 655      972490.0  tt10006422   tvMovie
# 870      974152.0  tt10009314   tvMovie
# 1549     977406.0  tt10015036   tvMovie
# ...           ...         ...       ...
# 300451  6587871.0   tt9908916   tvMovie
# 300975  6590161.0   tt9913680   tvMovie
# 301155  6591048.0   tt9915520   tvMovie
# 301240  6591316.0   tt9916112   tvMovie
# 301247  6591353.0   tt9916192   tvMovie
#
#                                        primaryTitle  \
# 10                            Great Bear Rainforest
# 77                   La Sagi, una pionera del Barça
# 655                        Warrior Women of Dahomey
# 870                  Peter Kraus: Immer in Bewegung
# 1549                      Arts Across the Heartland
# ...                                             ...
# 300451        Restless Legs Syndrome: The New Cure?
# 300975                        Olympiad drömmen 2020
# ...
