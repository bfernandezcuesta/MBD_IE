# %%
# Imports
import csv
import pandas as pd
import numpy as np

# %%
# Reading CVS files for each year
cds_2016 = pd.read_csv('CDS_2016_va.csv',  encoding="ISO-8859-1")
cds_2017 = pd.read_csv('CDS_2017_va.csv',  encoding="ISO-8859-1")
cds_2018 = pd.read_csv('CDS_2018_va.csv',  encoding="ISO-8859-1")
cds_2019 = pd.read_csv('CDS_2019_NO_LABEL.csv',  encoding="ISO-8859-1")

# %%
cds_2016.columns
# Out:
# Index(['Id_Cliente', 'Año Natural', 'Curso', 'Asignatura',
#        'Tipo Material Educativo', 'Grupo Editorial', 'Lengua',
#        'Tipo Soporte Actual', 'Variable 1', 'Variable 2'],
#       dtype='object')

# %%
cds_2016.columns = ['Id_Cliente', 'Ano', 'Curso', 'Asignatura', 'TipoMaterial', 'GrupoEditorial', 'Lengua', 'TipoSoporte', 'Clase', 'ValorClase']
cds_2017.columns = ['Id_Cliente', 'Ano', 'Curso', 'Asignatura', 'TipoMaterial', 'GrupoEditorial', 'Lengua', 'TipoSoporte', 'Clase', 'ValorClase']
cds_2018.columns = ['Id_Cliente', 'Ano', 'Curso', 'Asignatura', 'TipoMaterial', 'GrupoEditorial', 'Lengua', 'TipoSoporte', 'Clase', 'ValorClase']
cds_2019.columns = ['Id_Cliente', 'Ano', 'Curso', 'Asignatura', 'TipoMaterial', 'Lengua', 'TipoSoporte', 'Clase', 'ValorClase']

# %%
# Feature 'Curso' for the 2018 dataset has a 'c' character prior to each code. We will remove it and convert the column to integer type.
cds_2018['Curso'] = cds_2018['Curso'].replace('c', '', regex=True)
cds_2018['Curso'] = cds_2018['Curso'].astype(int)

# %%
# Modifying the value for year in 2018 dataset:
cds_2018['Ano'] = 2018

# %% [markdown]
# We will create an artificial ID to identify unique combinations, based on the combination of the following features:
# Id-Cliente, Curso, Asignatura, TipoMaterial, GrupoEditorial, Lengua, TipoSoporte

# %%
cds_2016['art_id'] = cds_2016.apply(lambda row:str(row.Id_Cliente)+str(row.Curso)+str(row.Asignatura)+str(row.TipoMaterial)+str(row.Lengua)+str(row.TipoSoporte), axis=1)
cds_2016['art_id'] = cds_2016.apply(lambda row:str(row.Id_Cliente)+str(row.Curso)+str(row.Asignatura)+str(row.TipoMaterial)+str(row.Lengua)+str(row.TipoSoporte), axis=1)
cds_2016
# Out:
#         Id_Cliente   Ano  Curso  Asignatura  TipoMaterial  GrupoEditorial  \
# 0           113958  2016     27          65             3              31
# 1           113958  2016     27          53             2              31
# 2           113958  2016     24          79             1              90
# 3           113958  2016     26          53             3              31
# 4           113958  2016     28          48             1              90
# ...            ...   ...    ...         ...           ...             ...
# 612722      210778  2016     37          61             1              90
# 612723      210778  2016     37          50             1              90
# 612724      210778  2016     37           7             1               1
# 612725      210778  2016     36          42             1              90
# 612726      210778  2016     37          48             1              90
#
#         Lengua  TipoSoporte  Clase  ValorClase          art_id
# ...

# %%
cds_2017['art_id'] = cds_2017.apply(lambda row:str(row.Id_Cliente)+str(row.Curso)+str(row.Asignatura)+str(row.TipoMaterial)+str(row.Lengua)+str(row.TipoSoporte), axis=1)
cds_2017['art_id'] = cds_2017.apply(lambda row:str(row.Id_Cliente)+str(row.Curso)+str(row.Asignatura)+str(row.TipoMaterial)+str(row.Lengua)+str(row.TipoSoporte), axis=1)
cds_2017
# Out:
#         Id_Cliente   Ano  Curso  Asignatura  TipoMaterial  GrupoEditorial  \
# 0           113956  2017     35           8             1               3
# 1           113956  2017     33          40             1               3
# 2           113956  2017     32          73             1              90
# 3           113956  2017     32          65             3              13
# 4           113956  2017     32          65             3              13
# ...            ...   ...    ...         ...           ...             ...
# 646337      211751  2017     34          79             1              90
# 646338      211751  2017     34          48             3               3
# 646339      211751  2017     34          65             1               3
# 646340      211817  2017     25          79             1               6
# 646341      211817  2017     23         243             1               6
#
#         Lengua  TipoSoporte  Clase  ValorClase           art_id
# ...

# %%
cds_2018['art_id'] = cds_2018.apply(lambda row:str(row.Id_Cliente)+str(row.Curso)+str(row.Asignatura)+str(row.TipoMaterial)+str(row.Lengua)+str(row.TipoSoporte), axis=1)
cds_2018['art_id'] = cds_2018.apply(lambda row:str(row.Id_Cliente)+str(row.Curso)+str(row.Asignatura)+str(row.TipoMaterial)+str(row.Lengua)+str(row.TipoSoporte), axis=1)
cds_2018
# Out:
#         Id_Cliente   Ano  Curso  Asignatura  TipoMaterial  GrupoEditorial  \
# 0           113956  2018     35          37             1               3
# 1           113956  2018     33          37             1               5
# 2           113956  2018     34          48             3              10
# 3           113956  2018     35          47             1              90
# 4           113956  2018     35          82             1              90
# ...            ...   ...    ...         ...           ...             ...
# 619849      212536  2018     37           7             1              16
# 619850      212536  2018     36         241             1               5
# 619851      212536  2018     37          48             2               4
# 619852      212536  2018     37          39             1               2
# 619853      212536  2018     37          42             1               2
#
#         Lengua  TipoSoporte  Clase  ValorClase           art_id
# ...

# %%
cds_2019['art_id'] = cds_2019.apply(lambda row:str(row.Id_Cliente)+str(row.Curso)+str(row.Asignatura)+str(row.TipoMaterial)+str(row.Lengua)+str(row.TipoSoporte), axis=1)
cds_2019['art_id'] = cds_2019.apply(lambda row:str(row.Id_Cliente)+str(row.Curso)+str(row.Asignatura)+str(row.TipoMaterial)+str(row.Lengua)+str(row.TipoSoporte), axis=1)
cds_2019
# Out:
#         Id_Cliente   Ano  Curso  Asignatura  TipoMaterial  Lengua  \
# 0           113956  2019     33          48             3      13
# 1           113956  2019     33          65             1      26
# 2           113956  2019     32           8             1      26
# 3           113956  2019     32          60             1      26
# 4           113956  2019     32          73             1      13
# ...            ...   ...    ...         ...           ...     ...
# 617855      212536  2019     36          48             1      13
# 617856      212536  2019     36          42             1      13
# 617857      212536  2019     36           8             1      10
# 617858      212536  2019     37          48             2      13
# 617859      212536  2019     37          42             1      13
#
#         TipoSoporte  Clase  ValorClase          art_id
# 0                 1  150.0     22.5150  11395633483131
# 1                 1   90.0     22.1760  11395633651261
# ...

# %%
# Creating DataFrames for each year, to analiyze the change of GrupoEditorial between years:
t2016 = cds_2016[['art_id', 'GrupoEditorial']]
t2017 = cds_2017[['art_id', 'GrupoEditorial']]
t2018 = cds_2018[['art_id', 'GrupoEditorial']]

# %%
target2017 = (pd.merge(t2016, t2017, on='art_id'))
target2017
# Out:
#                 art_id  GrupoEditorial_x  GrupoEditorial_y
# 0       11395827653261                31                31
# 1       11395827532261                31                31
# 2       11395824791261                90                90
# 3       11395826533261                31                31
# 4       11395828481131                90                90
# ...                ...               ...               ...
# 538936  21077837621131                90                90
# 538937  21077836261131                90                90
# 538938  21077837431131                34                34
# 538939  21077837611131                90                90
# 538940  21077837481131                90                90
#
# [538941 rows x 3 columns]

# %%
target2018 = (pd.merge(t2017, t2018, on='art_id'))
target2018
# Out:
#                 art_id  GrupoEditorial_x  GrupoEditorial_y
# 0        1139563581261                 3                 3
# 1       11395633401261                 3                 3
# 2       11395635541131                 3                 3
# 3       11395635371261                 3                 3
# 4       11395632531262                 3                 5
# ...                ...               ...               ...
# 548439  21181723631131                 5                 5
# 548440  21181723481131                34                34
# 548441  21181723512131                 6                 6
# 548442  21181724512131                 6                 6
# 548443  21181723791131                 6                 6
#
# [548444 rows x 3 columns]

# %%
# Creating the Target variable for 2016-2017 and 2017-2018:

def target_var(dataframe):
    if (dataframe.GrupoEditorial_y == 90) and (dataframe.GrupoEditorial_x != 90):
        return (1)
    else :
        return (0)

target2017['target'] = target2017.apply(target_var, axis=1)
target2018['target'] = target2018.apply(target_var, axis=1)

# %%
target2017 = target2017.drop(columns=['GrupoEditorial_x', 'GrupoEditorial_y'])

# %%
target2018 = target2018.drop(columns=['GrupoEditorial_x', 'GrupoEditorial_y'])

# %%
final_target2017 = (pd.merge(target2017, cds_2017, on='art_id'))

# %%
final_target2018 = (pd.merge(target2018, cds_2018, on='art_id'))

# %%
# Validating that the Target has been assigned correctly:
final_target2018.loc[final_target2018['art_id'] == '21066335821131']
# Out:
#                 art_id  target  Id_Cliente   Ano  Curso  Asignatura  \
# 545688  21066335821131       0      210663  2018     35          82
#
#         TipoMaterial  GrupoEditorial  Lengua  TipoSoporte  Clase  ValorClase
# 545688             1               1      13            1   10.0       282.8

# %% [markdown]
# Merging dataframes with target variable from different years:

# %%
cds_final = (pd.merge(final_target2017, final_target2018, on=['art_id', 'Id_Cliente', 'Curso', 'Asignatura', 'TipoMaterial', 'Lengua', 'TipoSoporte'], how="outer"))

# %%
cds_final
# Out:
#                 art_id  target_x  Id_Cliente   Ano_x  Curso  Asignatura  \
# 0       11395827653261       0.0      113958  2017.0     27          65
# 1       11395827532261       0.0      113958  2017.0     27          53
# 2       11395824791261       0.0      113958  2017.0     24          79
# 3       11395826533261       0.0      113958  2017.0     26          53
# 4       11395828481131       0.0      113958  2017.0     28          48
# ...                ...       ...         ...     ...    ...         ...
# 764623  21181723631131       NaN      211817     NaN     23          63
# 764624  21181723481131       NaN      211817     NaN     23          48
# 764625  21181723512131       NaN      211817     NaN     23          51
# 764626  21181724512131       NaN      211817     NaN     24          51
# 764627  21181723791131       NaN      211817     NaN     23          79
#
#         TipoMaterial  GrupoEditorial_x  Lengua  TipoSoporte  Clase_x  \
# ...

# %% [markdown]
# Mapping columns according to the year that each record belongs to, since we need an Outer join:

# %%
cds_final['Ano_y'] = cds_final.apply(
    lambda row: row['Ano_x'] if np.isnan(row['Ano_y']) else row['Ano_y'],
    axis=1
)

# %%
# Keeping Grupo Editorial from previous year, since it should have a high significance for the model:
cds_final['GrupoEditorial_x'] = cds_final.apply(
    lambda row: row['GrupoEditorial_y'] if np.isnan(row['GrupoEditorial_x']) else row['GrupoEditorial_x'],
    axis=1
)

# %%
cds_final['Clase_y'] = cds_final.apply(
    lambda row: row['Clase_x'] if np.isnan(row['Clase_y']) else row['Clase_y'],
    axis=1
)

# %%
cds_final['ValorClase_y'] = cds_final.apply(
    lambda row: row['ValorClase_x'] if np.isnan(row['ValorClase_y']) else row['ValorClase_y'],
    axis=1
)

# %%
cds_final['target_y'] = cds_final.apply(
    lambda row: row['target_x'] if np.isnan(row['target_y']) else row['target_y'],
    axis=1
)

# %%
cds_final = cds_final.drop(columns=['Ano_x', 'Clase_x', 'ValorClase_x', 'target_x'])

# %%
cds_final.rename(columns={"GrupoEditorial_x": "GrupoEditorialPrevio", "GrupoEditorial_y": "GrupoEditorialActual", "target_y": "Target", "Ano_y": "Ano", "Clase_y": "Clase", "ValorClase_y": "ValorClase"}, inplace=True)

# %%
cds_final.loc[cds_final['art_id'] == '21066335821131']
# Out:
#                 art_id  Id_Cliente  Curso  Asignatura  TipoMaterial  \
# 677086  21066335821131      210663     35          82             1
#
#         GrupoEditorialPrevio  Lengua  TipoSoporte  Target     Ano  \
# 677086                  90.0      13            1     0.0  2018.0
#
#         GrupoEditorialActual  Clase  ValorClase
# 677086                   1.0   10.0       282.8

# %%
cds_final.isna().sum()
# Out:
# art_id                      0
# Id_Cliente                  0
# Curso                       0
# Asignatura                  0
# TipoMaterial                0
# GrupoEditorialPrevio        0
# Lengua                      0
# TipoSoporte                 0
# Target                      0
# Ano                         0
# GrupoEditorialActual    85114
# Clase                       0
# ValorClase                  0
# dtype: int64

# %%
cds_final.sample(20)
# Out:
#                  art_id  Id_Cliente  Curso  Asignatura  TipoMaterial  \
# 376617   16672026651101      166720     26          65             1
# 489451   17202833401181      172028     33          40             1
# 541568   17420334531261      174203     34          53             1
# 228275   13499929601131      134999     29          60             1
# 316835   13836027481131      138360     27          48             1
# 20263    11500428601131      115004     28          60             1
# 684876   11763031532101      117630     31          53             2
# 673364   20960926651101      209609     26          65             1
# 313692   13831423481131      138314     23          48             1
# 112221   12434532791131      124345     32          79             1
# 498085   17241134383131      172411     34          38             3
# 474018   17143635481131      171436     35          48             1
# 283525   13734326602131      137343     26          60             2
# ...

# %% [markdown]
# Adding client features to the final training set:

# %%
maestros = pd.read_csv('Maestros.csv')

# %%
maestros.sample(5)
# Out:
#       Id_Cliente    Latitud   Longitud ComunidadAutonoma Titularidad
# 8833      127212  42.031399  -1.651978           Navarra     Público
# 8027      192228  40.303489  -3.727364            Madrid     Privado
# 6297      136449  40.476117  -3.729902            Madrid    Católico
# 9414      171479  43.291887  -2.353730        País Vasco     Público
# 5944      174355  28.639741 -17.875880    Islas Canarias     Público

# %%
training = (pd.merge(cds_final, maestros, on='Id_Cliente', how="left"))

# %%
training.isna().sum()
# Out:
# art_id                      0
# Id_Cliente                  0
# Curso                       0
# Asignatura                  0
# TipoMaterial                0
# GrupoEditorialPrevio        0
# Lengua                      0
# TipoSoporte                 0
# Target                      0
# Ano                         0
# GrupoEditorialActual    85114
# Clase                       0
# ValorClase                  0
# Latitud                     0
# Longitud                    0
# ComunidadAutonoma           0
# Titularidad                 0
# dtype: int64

# %%
training.sample(5)
# Out:
#                 art_id  Id_Cliente  Curso  Asignatura  TipoMaterial  \
# 763299  21094427483131      210944     27          48             3
# 193213  13333731481131      133337     31          48             1
# 186226  13325526731131      133255     26          73             1
# 646289  20234635381131      202346     35          38             1
# 105773  12299934371261      122999     34          37             1
#
#         GrupoEditorialPrevio  Lengua  TipoSoporte  Target     Ano  \
# 763299                   3.0      13            1     0.0  2018.0
# 193213                   3.0      13            1     0.0  2018.0
# 186226                  90.0      13            1     0.0  2018.0
# 646289                   3.0      13            1     0.0  2018.0
# 105773                  90.0      26            1     0.0  2018.0
#
#         GrupoEditorialActual  Clase  ValorClase    Latitud  Longitud  \
# 763299                   3.0   55.0      506.55  38.363372 -0.470585
# ...

# %%
training['ComunidadAutonoma'].replace(['Cataluña','Comunidad Valenciana', 'Islas Canarias', 'La Rioja', 'Madrid', 'Navarra', 'País Vasco'],[1,2,3,4,5,6,7],inplace=True)
training['Titularidad'].replace(['Católico', 'Privado', 'Público'],[1,2,3],inplace=True)

# %%
training.sample(5)
# Out:
#                 art_id  Id_Cliente  Curso  Asignatura  TipoMaterial  \
# 704282  13394130131181      133941     30          13             1
# 51445   11742831481131      117428     31          48             1
# 427062  16919029481131      169190     29          48             1
# 570023  17543836611101      175438     36          61             1
# 36569   11722330483131      117223     30          48             3
#
#         GrupoEditorialPrevio  Lengua  TipoSoporte  Target     Ano  \
# 704282                   8.0      18            1     0.0  2018.0
# 51445                    3.0      13            1     0.0  2018.0
# 427062                  10.0      13            1     0.0  2018.0
# 570023                   9.0      10            1     0.0  2018.0
# 36569                    4.0      13            1     0.0  2018.0
#
#         GrupoEditorialActual  Clase  ValorClase    Latitud  Longitud  \
# 704282                   8.0   58.0     1100.26  39.501257 -0.423230
# ...

# %% [markdown]
# Changing the Target to 0, for rows that do not exist in 2018 and Grupo Editorial Previo is 90 and for rows that turned to 90 in 2017 and stayed as 90 in 2018:

# %%
training['Target'] = training.apply(
    lambda row: 0 if (row['GrupoEditorialPrevio']==90 and row['GrupoEditorialActual']==90) else row['Target'],
    axis=1
)

# %%
training['Target'] = training.apply(
    lambda row: 0 if (row['GrupoEditorialPrevio']==90 and row['Ano']==2017) else row['Target'],
    axis=1
)

# %% [markdown]
# #### Generating the final CSV file for Training the model:

# %%
training.to_csv('final_training.csv', sep=',')

# %% [markdown]
# We will add the previous Grupo Editorial (from 2018) to the 2019 test dataset. So that we can use that variable to predict the Target as well.

# %%
GrEd2018 = cds_2018[['art_id', 'GrupoEditorial']]

# %%
test2019 = (pd.merge(cds_2019, GrEd2018, on='art_id', how="left"))

# %%
test2019.isna().sum()
# Out:
# Id_Cliente            0
# Ano                   0
# Curso                 0
# Asignatura            0
# TipoMaterial          0
# Lengua                0
# TipoSoporte           0
# Clase                 0
# ValorClase            0
# art_id                0
# GrupoEditorial    81022
# dtype: int64

# %%
test2019.rename(columns={"GrupoEditorial": "GrupoEditorialPrevio"}, inplace=True)
test2019.sample(20)
# Out:
#         Id_Cliente   Ano  Curso  Asignatura  TipoMaterial  Lengua  \
# 279777      138329  2019     26          48             3      13
# 393645      169875  2019     33          48             3      13
# 49253       117493  2019     32          48             3      13
# 125069      127171  2019     28          15             1      13
# 136202      129270  2019     33          73             1      13
# 112318      125175  2019     29          48             3      13
# 21641       115099  2019     28          48             1      13
# 255134      137430  2019     36          61             1      13
# 431837      171888  2019     33          73             1      10
# 326761      166256  2019     37          26             1      13
# 293073      141840  2019     30          60             3      13
# 409239      170793  2019     28          73             1      10
# 613948      212316  2019     29          54             1      13
# ...

# %%
test = (pd.merge(test2019, maestros, on='Id_Cliente', how="left"))

# %%
test['ComunidadAutonoma'].replace(['Cataluña','Comunidad Valenciana', 'Islas Canarias', 'La Rioja', 'Madrid', 'Navarra', 'País Vasco'],[1,2,3,4,5,6,7],inplace=True)
test['Titularidad'].replace(['Católico', 'Privado', 'Público'],[1,2,3],inplace=True)

# %%
test
# Out:
#         Id_Cliente   Ano  Curso  Asignatura  TipoMaterial  Lengua  \
# 0           113956  2019     33          48             3      13
# 1           113956  2019     33          65             1      26
# 2           113956  2019     32           8             1      26
# 3           113956  2019     32          60             1      26
# 4           113956  2019     32          73             1      13
# ...            ...   ...    ...         ...           ...     ...
# 617855      212536  2019     36          48             1      13
# 617856      212536  2019     36          42             1      13
# 617857      212536  2019     36           8             1      10
# 617858      212536  2019     37          48             2      13
# 617859      212536  2019     37          42             1      13
#
#         TipoSoporte  Clase  ValorClase          art_id  GrupoEditorialPrevio  \
# 0                 1  150.0     22.5150  11395633483131                  10.0
# ...

# %% [markdown]
# #### Generating the final CSV file for Testing the model:

# %%
test.to_csv('test.csv', sep=',')

# %% [markdown]
# ### STOP:
# ### The code above will generate all the required files to execute the Machine Learning Pipeline code. Please make sure to execute such pipeline and generate the "predictions.csv" file before executing the code below:

# %%
predictions = pd.read_csv('predictions.csv')

# %%
test['art_id'] = test['art_id'].astype(int)

# %% [markdown]
# #### Final Prediction file to perform Business Analysis and generate insights. It contains geographic and client features:

# %%
final_2019 = (pd.merge(test, predictions, left_on='art_id', right_on='id'))

# %%
final_2019
# Out:
#         Id_Cliente   Ano  Curso  Asignatura  TipoMaterial  Lengua  \
# 0           113956  2019     33          48             3      13
# 1           113956  2019     33          65             1      26
# 2           113956  2019     32           8             1      26
# 3           113956  2019     32          60             1      26
# 4           113956  2019     32          73             1      13
# ...            ...   ...    ...         ...           ...     ...
# 533620      212536  2019     36          48             1      13
# 533621      212536  2019     36          42             1      13
# 533622      212536  2019     36           8             1      10
# 533623      212536  2019     37          48             2      13
# 533624      212536  2019     37          42             1      13
#
#         TipoSoporte  Clase  ValorClase          art_id  GrupoEditorialPrevio  \
# 0                 1  150.0     22.5150  11395633483131                  10.0
# ...

# %%
final_2019['Target'] = final_2019.apply(
    lambda row: 0 if (row['GrupoEditorialPrevio']==90) else row['Target'],
    axis=1
)

# %%
final_2019.to_csv('final_2019.csv', sep=',')

# %% [markdown]
# ### Generating the final 2019 prediction file in the required format, only containing rows that resulted from the join between 2018 - 2019:

# %%
final_2019
# Out:
#         Id_Cliente   Ano  Curso  Asignatura  TipoMaterial  Lengua  \
# 0           113956  2019     33          48             3      13
# 1           113956  2019     33          65             1      26
# 2           113956  2019     32           8             1      26
# 3           113956  2019     32          60             1      26
# 4           113956  2019     32          73             1      13
# ...            ...   ...    ...         ...           ...     ...
# 533620      212536  2019     36          48             1      13
# 533621      212536  2019     36          42             1      13
# 533622      212536  2019     36           8             1      10
# 533623      212536  2019     37          48             2      13
# 533624      212536  2019     37          42             1      13
#
#         TipoSoporte  Clase  ValorClase          art_id  GrupoEditorialPrevio  \
# 0                 1  150.0     22.5150  11395633483131                  10.0
# ...

# %%
CDS_2019_PRED = final_2019.drop(columns=['GrupoEditorialPrevio', 'Latitud', 'Longitud', 'ComunidadAutonoma', 'Titularidad', 'id', 'art_id'])

# %%
CDS_2019_PRED.rename(columns={"Ano": "Año natural", "Clase": "Variable1", "ValorClase": "Variable2"}, inplace=True)

# %%
CDS_2019_PRED
# Out:
#         Id_Cliente  Año natural  Curso  Asignatura  TipoMaterial  Lengua  \
# 0           113956         2019     33          48             3      13
# 1           113956         2019     33          65             1      26
# 2           113956         2019     32           8             1      26
# 3           113956         2019     32          60             1      26
# 4           113956         2019     32          73             1      13
# ...            ...          ...    ...         ...           ...     ...
# 533620      212536         2019     36          48             1      13
# 533621      212536         2019     36          42             1      13
# 533622      212536         2019     36           8             1      10
# 533623      212536         2019     37          48             2      13
# 533624      212536         2019     37          42             1      13
#
#         TipoSoporte  Variable1  Variable2  Target
# ...

# %%
CDS_2019_PRED.to_csv('CDS_2019_PRED.csv', sep=',')
